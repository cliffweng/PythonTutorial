# %%
# %matplotlib inline
import Quandl
TOKEN = 'CcvxGpSfz4q2bZxnq2YQ' # Replace None by your own Quandl token

# %%
uk_df = Quandl.get('OECD/HEALTH_STAT_CICDHOCD_TXCMILTX_GBR', authtoken=TOKEN)

# %%
uk_df.plot()

# %%
from pandas import read_csv
##crime = Quandl.get('FBI_UCR/USCRIME_TYPE_VIOLENTCRIMERATE', authtoken=TOKEN)
##crime.to_csv('./data/crime.csv')
crime2=read_csv('./data/crime.csv', index_col='Year')
crime2
# Out:
#             Alabama  Alaska  Arizona  Arkansas  California  Colorado  \
# Year
# 1960-12-31    186.6   104.3    207.7     107.7       239.0     137.3
# 1961-12-31    168.5    88.9    164.5     100.7       232.7     149.3
# 1962-12-31    157.3    91.5    173.0      91.4       234.8     156.8
# 1963-12-31    182.7   109.7    194.2     107.2       241.2     130.3
# 1964-12-31    213.1   150.0    213.0     136.6       265.6     158.6
# 1965-12-31    199.8   149.0    192.3     135.8       282.2     152.7
# 1966-12-31    230.3   150.4    202.2     162.9       305.1     168.9
# 1967-12-31    238.6   160.7    238.2     219.5       352.1     191.8
# 1968-12-31    232.4   175.5    263.6     216.7       422.9     263.0
# 1969-12-31    250.4   221.3    339.2     220.1       462.3     298.8
# 1970-12-31    295.7   278.0    370.3     222.3       474.8     356.7
# 1971-12-31    311.4   355.3    400.6     240.7       518.6     373.6
# ...
